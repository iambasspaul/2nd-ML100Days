# %% [markdown]
# # 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
#
# ANS:
# 1. 我選的資料租為 "Home Credit Default Risk", 銀行利用相關數據來快速完成信用情況審核, 可讓急需有資金的人快速核貸, 減少被騙錢的可能。
#
# 2. 供應資料人員:"Home Credit Group", 資料是該單位提供貸款所需的相關資料。
#
# 3. 資料型態有浮點數、整數、字串及二元數等。
#
# 4. 要以現有通訊紀錄及交易資料來預測客戶還款能力。
#
#
#
# #作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#
# ANS:
# 1. 核心問題為如何提升業績, 假設以Google地圖的人群流量來預測可能乘車客人。
#
# 2. 資料從Facebook的地點打卡人數，並結合Google地圖人群流量來預測可能人流。
#
# 3. 資料有地圖經緯度的浮點數及打卡人數的資料型態。
#
# 4. 以每日增加的打卡人數和實際的載客人數比較，來評估人數載客人數的多少。
#
#
# #作業3：
#
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：2nd-ML100Days > data資料夾 & homework資料夾 (ipynb檔)
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %% [markdown]
# 練習時間
# 請寫一個函式用來計算 Mean Square Error
# 𝑀𝑆𝐸=1𝑛∑𝑛𝑖=1(𝑌𝑖−𝑌̂ 𝑖)2
# Hint: 如何取平方

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, y_hat):
    sumup=0
    """
    請完成這個 Function 後往下執行
    sumup = 0
    for i in range(len(y)):
        sumup = sumup + (y[i]-y_hat[i])**2
        
    sumup =(1/len(y))*sumup
    """
    sumup = sum((y-y_hat)**2)/len(y)
    return sumup

# %%
def mean_absolute_error(y, y_hat):
    sumup =0
    '''
     for i in range(len(y)):
        sumup = sumup + abs(y[i]-y_hat[i])
    
    sumup =(1/len(y))*sumup
    '''
    sumup = sum(abs(y-y_hat))/len(y)
    return sumup

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 168.701
# The Mean absolute error is 9.904
